# %%
pip install llama_index

# %%
from llama_index.core import PromptTemplate

# %%
import csv

# Open the CSV file in read mode
textlist=[]

with open('xlxFile.csv', 'r', newline='') as csvfile:
    # Create a CSV reader object
    csv_reader = csv.reader(csvfile)

    # Iterate over each row in the CSV file
    for row in csv_reader:
        # Each row will be treated as a list of strings
        # Convert it into a single string if needed
        row_string = ','.join(row)
        textlist.append(row_string)
        #print(row_string)

textlist[1]

# %%
section_criteriaS=["Inability to make medical decisions (Discharged - mental status / consciousness)"]
qa_prompt_tmpl_str_var26= """\
Your job is to decide which of the following inclusion criteria the given patient meets.
Below is a clinical note describing the patient's current health status:
---------------------
{note}
---------------------
The inclusion criteria being assessed is listed below:
{section_criteria}
---------------------
For the criteria above, use the patient's clinical note to determine whether the patient meets each criteria. Think step by step, and
justify your answer.
Format your response as a variable with following type:
* Inability to make medical decisions (Discharged - mental status / consciousness): int , 1 if present, 0 if not present

An example of how your  response should be formatted is shown below:

Inability to make medical decisions (Discharged - mental status / consciousness): 1/0

The above example is only for illustration purposes only. It does not reflect the actual criteria or patient for this task.
Please analyze the given patient and inclusion criteria. Remember to include  inclusion criteria in your returned response. Please
provide your response:
"""

prompt_tmpl = PromptTemplate(qa_prompt_tmpl_str_var26)

# %%
partial_prompt_tmpl = prompt_tmpl.partial_format(tone_name="Shakespeare")
fmt_prompt = partial_prompt_tmpl.format(
    section_criteria=section_criteriaS,
    note=noteS,
)
print(fmt_prompt)

# %%
section_criteriaS=["Major depressive disorder / Depression"]
qa_prompt_tmpl_str_var25= """\
Your job is to decide which of the following inclusion criteria the given patient meets.
Below is a clinical note describing the patient's current health status:
---------------------
{note}
---------------------
The inclusion criteria being assessed is listed below:
{section_criteria}
---------------------
For the criteria above, use the patient's clinical note to determine whether the patient meets each criteria. Think step by step, and
justify your answer.
Format your response as a variable with following type:
* Major depressive disorder / Depression: int , 1 if present, 0 if not present

An example of how your  response should be formatted is shown below:

Major depressive disorder / Depression: 1/0

The above example is only for illustration purposes only. It does not reflect the actual criteria or patient for this task.
Please analyze the given patient and inclusion criteria. Remember to include  inclusion criteria in your returned response. Please
provide your response:
"""

prompt_tmpl = PromptTemplate(qa_prompt_tmpl_str_var25)
partial_prompt_tmpl = prompt_tmpl.partial_format(tone_name="Shakespeare")
fmt_prompt = partial_prompt_tmpl.format(
    section_criteria=section_criteriaS,
    note=noteS,
)
print(fmt_prompt)

# %%
section_criteriaS=["Schizophrenic"]
qa_prompt_tmpl_str_var24= """\
Your job is to decide which of the following inclusion criteria the given patient meets.
Below is a clinical note describing the patient's current health status:
---------------------
{note}
---------------------
The inclusion criteria being assessed is listed below:
{section_criteria}
---------------------
For the criteria above, use the patient's clinical note to determine whether the patient meets each criteria. Think step by step, and
justify your answer.
Format your response as a variable with following type:
* Schizophrenic: int , 1 if present, 0 if not present

An example of how your  response should be formatted is shown below:

Schizophrenic: 1/0

The above example is only for illustration purposes only. It does not reflect the actual criteria or patient for this task.
Please analyze the given patient and inclusion criteria. Remember to include  inclusion criteria in your returned response. Please
provide your response:
"""

prompt_tmpl = PromptTemplate(qa_prompt_tmpl_str_var24)
partial_prompt_tmpl = prompt_tmpl.partial_format(tone_name="Shakespeare")
fmt_prompt = partial_prompt_tmpl.format(
    section_criteria=section_criteriaS,
    note=noteS,
)
print(fmt_prompt)

# %%
section_criteriaS=["Bipolar"]
qa_prompt_tmpl_str_var23= """\
Your job is to decide which of the following inclusion criteria the given patient meets.
Below is a clinical note describing the patient's current health status:
---------------------
{note}
---------------------
The inclusion criteria being assessed is listed below:
{section_criteria}
---------------------
For the criteria above, use the patient's clinical note to determine whether the patient meets each criteria. Think step by step, and
justify your answer.
Format your response as a variable with following type:
* Bipolar: int , 1 if present, 0 if not present

An example of how your  response should be formatted is shown below:

Bipolar: 1/0

The above example is only for illustration purposes only. It does not reflect the actual criteria or patient for this task.
Please analyze the given patient and inclusion criteria. Remember to include  inclusion criteria in your returned response. Please
provide your response:
"""

prompt_tmpl = PromptTemplate(qa_prompt_tmpl_str_var23)
partial_prompt_tmpl = prompt_tmpl.partial_format(tone_name="Shakespeare")
fmt_prompt = partial_prompt_tmpl.format(
    section_criteria=section_criteriaS,
    note=noteS,
)
print(fmt_prompt)

# %%
section_criteriaS=["max total bilirubin (TotBili, Bili)"]
qa_prompt_tmpl_str_var22= """\
Your job is to decide which of the following inclusion criteria the given patient meets.
Below is a clinical note describing the patient's current health status:
---------------------
{note}
---------------------
The inclusion criteria being assessed is listed below:
{section_criteria}
---------------------
For the criteria above, use the patient's clinical note to determine whether the patient meets each criteria. Think step by step, and
justify your answer.
Format your response as a variable with following type:
* max total bilirubin (TotBili, Bili): float , a number, -1 if no level listed

An example of how your  response should be formatted is shown below:

max total bilirubin (TotBili, Bili): a number

The above example is only for illustration purposes only. It does not reflect the actual criteria or patient for this task.
Please analyze the given patient and inclusion criteria. Remember to include  inclusion criteria in your returned response. Please
provide your response:
"""

prompt_tmpl = PromptTemplate(qa_prompt_tmpl_str_var22)
partial_prompt_tmpl = prompt_tmpl.partial_format(tone_name="Shakespeare")
fmt_prompt = partial_prompt_tmpl.format(
    section_criteria=section_criteriaS,
    note=noteS,
)
print(fmt_prompt)

# %%
section_criteriaS=["max aspartate aminotransferase level (AST)"]
qa_prompt_tmpl_str_var21= """\
Your job is to decide which of the following inclusion criteria the given patient meets.
Below is a clinical note describing the patient's current health status:
---------------------
{note}
---------------------
The inclusion criteria being assessed is listed below:
{section_criteria}
---------------------
For the criteria above, use the patient's clinical note to determine whether the patient meets each criteria. Think step by step, and
justify your answer.
Format your response as a variable with following type:
* max aspartate aminotransferase level (AST): int , a number , -1 if no level listed

An example of how your  response should be formatted is shown below:

max aspartate aminotransferase level (AST): a number

The above example is only for illustration purposes only. It does not reflect the actual criteria or patient for this task.
Please analyze the given patient and inclusion criteria. Remember to include  inclusion criteria in your returned response. Please
provide your response:
"""

prompt_tmpl = PromptTemplate(qa_prompt_tmpl_str_var21)
partial_prompt_tmpl = prompt_tmpl.partial_format(tone_name="Shakespeare")
fmt_prompt = partial_prompt_tmpl.format(
    section_criteria=section_criteriaS,
    note=noteS,
)
print(fmt_prompt)

# %%
section_criteriaS=["max serum creatine  (Creat)"]
qa_prompt_tmpl_str_var20= """\
Your job is to decide which of the following inclusion criteria the given patient meets.
Below is a clinical note describing the patient's current health status:
---------------------
{note}
---------------------
The inclusion criteria being assessed is listed below:
{section_criteria}
---------------------
For the criteria above, use the patient's clinical note to determine whether the patient meets each criteria. Think step by step, and
justify your answer.
Format your response as a variable with following type:
* max serum creatine  (Creat): float, a number , -1 if no level listed

An example of how your  response should be formatted is shown below:

max serum creatine  (Creat): a number

The above example is only for illustration purposes only. It does not reflect the actual criteria or patient for this task.
Please analyze the given patient and inclusion criteria. Remember to include  inclusion criteria in your returned response. Please
provide your response:
"""

prompt_tmpl = PromptTemplate(qa_prompt_tmpl_str_var20)
partial_prompt_tmpl = prompt_tmpl.partial_format(tone_name="Shakespeare")
fmt_prompt = partial_prompt_tmpl.format(
    section_criteria=section_criteriaS,
    note=noteS,
)
print(fmt_prompt)

# %%
section_criteriaS=["Drug abuse - Generally not available in mimic iv - just list as -1"]
qa_prompt_tmpl_str_var19= """\
Your job is to decide which of the following inclusion criteria the given patient meets.
Below is a clinical note describing the patient's current health status:
---------------------
{note}
---------------------
The inclusion criteria being assessed is listed below:
{section_criteria}
---------------------
For the criteria above, use the patient's clinical note to determine whether the patient meets each criteria. Think step by step, and
justify your answer.
Format your response as a variable with following type:
* Drug abuse - Generally not available in mimic iv - just list as -1: int , a number, 1 if present, 0 if not present, -1 if not able to tell

An example of how your  response should be formatted is shown below:

Drug abuse - Generally not available in mimic iv - just list as -1: a number

The above example is only for illustration purposes only. It does not reflect the actual criteria or patient for this task.
Please analyze the given patient and inclusion criteria. Remember to include  inclusion criteria in your returned response. Please
provide your response:
"""

prompt_tmpl = PromptTemplate(qa_prompt_tmpl_str_var19)
partial_prompt_tmpl = prompt_tmpl.partial_format(tone_name="Shakespeare")
fmt_prompt = partial_prompt_tmpl.format(
    section_criteria=section_criteriaS,
    note=noteS,
)
print(fmt_prompt)

# %%
section_criteriaS=["Alcohol abuse - Generally not available in mimic iv - just list as -1"]
qa_prompt_tmpl_str_var18= """\
Your job is to decide which of the following inclusion criteria the given patient meets.
Below is a clinical note describing the patient's current health status:
---------------------
{note}
---------------------
The inclusion criteria being assessed is listed below:
{section_criteria}
---------------------
For the criteria above, use the patient's clinical note to determine whether the patient meets each criteria. Think step by step, and
justify your answer.
Format your response as a variable with following type:
* Alcohol abuse - Generally not available in mimic iv - just list as -1: int , a number, 1 if present, 0 if not present, -1 if not able to tell

An example of how your  response should be formatted is shown below:

Alcohol abuse - Generally not available in mimic iv - just list as -1: a number

The above example is only for illustration purposes only. It does not reflect the actual criteria or patient for this task.
Please analyze the given patient and inclusion criteria. Remember to include  inclusion criteria in your returned response. Please
provide your response:
"""

prompt_tmpl = PromptTemplate(qa_prompt_tmpl_str_var18)
partial_prompt_tmpl = prompt_tmpl.partial_format(tone_name="Shakespeare")
fmt_prompt = partial_prompt_tmpl.format(
    section_criteria=section_criteriaS,
    note=noteS,
)
print(fmt_prompt)

# %%
section_criteriaS=["Documented hemorrhagic tendencies or blood dyscrasias"]
qa_prompt_tmpl_str_var17= """\
Your job is to decide which of the following inclusion criteria the given patient meets.
Below is a clinical note describing the patient's current health status:
---------------------
{note}
---------------------
The inclusion criteria being assessed is listed below:
{section_criteria}
---------------------
For the criteria above, use the patient's clinical note to determine whether the patient meets each criteria. Think step by step, and
justify your answer.
Format your response as a variable with following type:
* Documented hemorrhagic tendencies or blood dyscrasias: int , 1 if present, 0 if not present

An example of how your  response should be formatted is shown below:

Documented hemorrhagic tendencies or blood dyscrasias: 1/0

The above example is only for illustration purposes only. It does not reflect the actual criteria or patient for this task.
Please analyze the given patient and inclusion criteria. Remember to include  inclusion criteria in your returned response. Please
provide your response:
"""

prompt_tmpl = PromptTemplate(qa_prompt_tmpl_str_var17)
partial_prompt_tmpl = prompt_tmpl.partial_format(tone_name="Shakespeare")
fmt_prompt = partial_prompt_tmpl.format(
    section_criteria=section_criteriaS,
    note=noteS,
)
print(fmt_prompt)

# %%
section_criteriaS=["Stroke during admission or 10 days prior (Flag if recent, not clear 10 days)"]
qa_prompt_tmpl_str_var16= """\
Your job is to decide which of the following inclusion criteria the given patient meets.
Below is a clinical note describing the patient's current health status:
---------------------
{note}
---------------------
The inclusion criteria being assessed is listed below:
{section_criteria}
---------------------
For the criteria above, use the patient's clinical note to determine whether the patient meets each criteria. Think step by step, and
justify your answer.
Format your response as a variable with following type:
* Stroke during admission or 10 days prior (Flag if recent, not clear 10 days): int , 1 if present, 0 if not present

An example of how your  response should be formatted is shown below:

Stroke during admission or 10 days prior (Flag if recent, not clear 10 days): 1/0

The above example is only for illustration purposes only. It does not reflect the actual criteria or patient for this task.
Please analyze the given patient and inclusion criteria. Remember to include  inclusion criteria in your returned response. Please
provide your response:
"""

prompt_tmpl = PromptTemplate(qa_prompt_tmpl_str_var16)
partial_prompt_tmpl = prompt_tmpl.partial_format(tone_name="Shakespeare")
fmt_prompt = partial_prompt_tmpl.format(
    section_criteria=section_criteriaS,
    note=noteS,
)
print(fmt_prompt)

# %%
section_criteriaS=["Minimum observed hemoglobin (HGB)"]
qa_prompt_tmpl_str_var15= """\
Your job is to decide which of the following inclusion criteria the given patient meets.
Below is a clinical note describing the patient's current health status:
---------------------
{note}
---------------------
The inclusion criteria being assessed is listed below:
{section_criteria}
---------------------
For the criteria above, use the patient's clinical note to determine whether the patient meets each criteria. Think step by step, and
justify your answer.
Format your response as a variable with following type:
* Minimum observed hemoglobin (HGB): float , -1 if no level listed

An example of how your  response should be formatted is shown below:

Minimum observed hemoglobin (HGB): a number

The above example is only for illustration purposes only. It does not reflect the actual criteria or patient for this task.
Please analyze the given patient and inclusion criteria. Remember to include  inclusion criteria in your returned response. Please
provide your response:
"""

prompt_tmpl = PromptTemplate(qa_prompt_tmpl_str_var15)
partial_prompt_tmpl = prompt_tmpl.partial_format(tone_name="Shakespeare")
fmt_prompt = partial_prompt_tmpl.format(
    section_criteria=section_criteriaS,
    note=noteS,
)
print(fmt_prompt)

# %%
section_criteriaS=["Minimum observed platelet count (PLT)"]
qa_prompt_tmpl_str_var14 = """\
Your job is to decide which of the following inclusion criteria the given patient meets.
Below is a clinical note describing the patient's current health status:
---------------------
{note}
---------------------
The inclusion criteria being assessed is listed below:
{section_criteria}
---------------------
For the criteria above, use the patient's clinical note to determine whether the patient meets each criteria. Think step by step, and
justify your answer.
Format your response as a variable with following type:
* Minimum observed platelet count (PLT): int , a number, -1 if no level listed

An example of how your  response should be formatted is shown below:

Minimum observed platelet count (PLT): a number

The above example is only for illustration purposes only. It does not reflect the actual criteria or patient for this task.
Please analyze the given patient and inclusion criteria. Remember to include  inclusion criteria in your returned response. Please
provide your response:
"""

prompt_tmpl = PromptTemplate(qa_prompt_tmpl_str_var14)
partial_prompt_tmpl = prompt_tmpl.partial_format(tone_name="Shakespeare")
fmt_prompt = partial_prompt_tmpl.format(
    section_criteria=section_criteriaS,
    note=noteS,
)
print(fmt_prompt)

# %%
section_criteriaS=["History Peptic Ulcer Disease"]
qa_prompt_tmpl_str_var13 = """\
Your job is to decide which of the following inclusion criteria the given patient meets.
Below is a clinical note describing the patient's current health status:
---------------------
{note}
---------------------
The inclusion criteria being assessed is listed below:
{section_criteria}
---------------------
For the criteria above, use the patient's clinical note to determine whether the patient meets each criteria. Think step by step, and
justify your answer.
Format your response as a variable with following type:
* History Peptic Ulcer Disease: int , 1 if present, 0 if not present, -1 if no medical history

An example of how your  response should be formatted is shown below:

History Peptic Ulcer Disease: 1/0/-1

The above example is only for illustration purposes only. It does not reflect the actual criteria or patient for this task.
Please analyze the given patient and inclusion criteria. Remember to include  inclusion criteria in your returned response. Please
provide your response:
"""

prompt_tmpl = PromptTemplate(qa_prompt_tmpl_str_var13)
partial_prompt_tmpl = prompt_tmpl.partial_format(tone_name="Shakespeare")
fmt_prompt = partial_prompt_tmpl.format(
    section_criteria=section_criteriaS,
    note=noteS,
)
print(fmt_prompt)

# %%
section_criteriaS=["Serious bleeding in last 6 months"]
qa_prompt_tmpl_str_var12 = """\
Your job is to decide which of the following inclusion criteria the given patient meets.
Below is a clinical note describing the patient's current health status:
---------------------
{note}
---------------------
The inclusion criteria being assessed is listed below:
{section_criteria}
---------------------
For the criteria above, use the patient's clinical note to determine whether the patient meets each criteria. Think step by step, and
justify your answer.
Format your response as a variable with following type:
* Serious bleeding in last 6 months: int , 1 if present, 0 if not present, -1 if no medical history

An example of how your  response should be formatted is shown below:

Serious bleeding in last 6 months: 1/0/-1

The above example is only for illustration purposes only. It does not reflect the actual criteria or patient for this task.
Please analyze the given patient and inclusion criteria. Remember to include  inclusion criteria in your returned response. Please
provide your response:
"""

prompt_tmpl = PromptTemplate(qa_prompt_tmpl_str_var12)
partial_prompt_tmpl = prompt_tmpl.partial_format(tone_name="Shakespeare")
fmt_prompt = partial_prompt_tmpl.format(
    section_criteria=section_criteriaS,
    note=noteS,
)
print(fmt_prompt)

# %%
section_criteriaS=["Planned or past ablation procedure for afib"]
qa_prompt_tmpl_str_var11 = """\
Your job is to decide which of the following inclusion criteria the given patient meets.
Below is a clinical note describing the patient's current health status:
---------------------
{note}
---------------------
The inclusion criteria being assessed is listed below:
{section_criteria}
---------------------
For the criteria above, use the patient's clinical note to determine whether the patient meets each criteria. Think step by step, and
justify your answer.
Format your response as a variable with following type:
* Planned or past ablation procedure for afib: int , 1 if present, 0 if not present, -1 if no medical history

An example of how your  response should be formatted is shown below:

Planned or past ablation procedure for afib: 1/0/-1

The above example is only for illustration purposes only. It does not reflect the actual criteria or patient for this task.
Please analyze the given patient and inclusion criteria. Remember to include  inclusion criteria in your returned response. Please
provide your response:
"""

prompt_tmpl = PromptTemplate(qa_prompt_tmpl_str_var11)
partial_prompt_tmpl = prompt_tmpl.partial_format(tone_name="Shakespeare")
fmt_prompt = partial_prompt_tmpl.format(
    section_criteria=section_criteriaS,
    note=noteS,
)
print(fmt_prompt)

# %%
section_criteriaS=["Valvular disease requiring or past surgery (stenosis)"]
qa_prompt_tmpl_str_var10 = """\
Your job is to decide which of the following inclusion criteria the given patient meets.
Below is a clinical note describing the patient's current health status:
---------------------
{note}
---------------------
The inclusion criteria being assessed is listed below:
{section_criteria}
---------------------
For the criteria above, use the patient's clinical note to determine whether the patient meets each criteria. Think step by step, and
justify your answer.
Format your response as a variable with following type:
* Valvular disease requiring or past surgery (stenosis): int , 1 if present, 0 if not present, -1 if no medical history

An example of how your  response should be formatted is shown below:

Valvular disease requiring or past surgery (stenosis): 1/0/-1

The above example is only for illustration purposes only. It does not reflect the actual criteria or patient for this task.
Please analyze the given patient and inclusion criteria. Remember to include  inclusion criteria in your returned response. Please
provide your response:
"""

prompt_tmpl = PromptTemplate(qa_prompt_tmpl_str_var10)
partial_prompt_tmpl = prompt_tmpl.partial_format(tone_name="Shakespeare")
fmt_prompt = partial_prompt_tmpl.format(
    section_criteria=section_criteriaS,
    note=noteS,
)
print(fmt_prompt)

# %%
section_criteriaS=["Left ventricular ejection fraction (lowest mentioned, LVEF, ef, ejection fraction)"]
qa_prompt_tmpl_str_var9 = """\
Your job is to decide which of the following inclusion criteria the given patient meets.
Below is a clinical note describing the patient's current health status:
---------------------
{note}
---------------------
The inclusion criteria being assessed is listed below:
{section_criteria}
---------------------
For the criteria above, use the patient's clinical note to determine whether the patient meets each criteria. Think step by step, and
justify your answer.
Format your response as a variable with following type:
* Left ventricular ejection fraction (lowest mentioned, LVEF, ef, ejection fraction): int , % if present, -1 if not in note, -2 if it was in note but filtered

An example of how your  response should be formatted is shown below:

Left ventricular ejection fraction (lowest mentioned, LVEF, ef, ejection fraction): a number

The above example is only for illustration purposes only. It does not reflect the actual criteria or patient for this task.
Please analyze the given patient and inclusion criteria. Remember to include  inclusion criteria in your returned response. Please
provide your response:
"""

prompt_tmpl = PromptTemplate(qa_prompt_tmpl_str_var9)
partial_prompt_tmpl = prompt_tmpl.partial_format(tone_name="Shakespeare")
fmt_prompt = partial_prompt_tmpl.format(
    section_criteria=section_criteriaS,
    note=noteS,
)
print(fmt_prompt)

# %%
section_criteriaS=["Heart Failure"]
qa_prompt_tmpl_str_var8 = """\
Your job is to decide which of the following inclusion criteria the given patient meets.
Below is a clinical note describing the patient's current health status:
---------------------
{note}
---------------------
The inclusion criteria being assessed is listed below:
{section_criteria}
---------------------
For the criteria above, use the patient's clinical note to determine whether the patient meets each criteria. Think step by step, and
justify your answer.
Format your response as a variable with following type:
* Heart Failure: int , 1 if present, 0  if not present, -1 if no history to tell

An example of how your  response should be formatted is shown below:

Heart Failure: 1/0/-1

The above example is only for illustration purposes only. It does not reflect the actual criteria or patient for this task.
Please analyze the given patient and inclusion criteria. Remember to include  inclusion criteria in your returned response. Please
provide your response:
"""

prompt_tmpl = PromptTemplate(qa_prompt_tmpl_str_var8)
partial_prompt_tmpl = prompt_tmpl.partial_format(tone_name="Shakespeare")
fmt_prompt = partial_prompt_tmpl.format(
    section_criteria=section_criteriaS,
    note=noteS,
)
print(fmt_prompt)

# %%
section_criteriaS=["Max A1c"]
qa_prompt_tmpl_str_var7 = """\
Your job is to decide which of the following inclusion criteria the given patient meets.
Below is a clinical note describing the patient's current health status:
---------------------
{note}
---------------------
The inclusion criteria being assessed is listed below:
{section_criteria}
---------------------
For the criteria above, use the patient's clinical note to determine whether the patient meets each criteria. Think step by step, and
justify your answer.
Format your response as a variable with following type:
* Max A1c: int , a number, -1 if no level listed

An example of how your  response should be formatted is shown below:

Max A1c: a number

The above example is only for illustration purposes only. It does not reflect the actual criteria or patient for this task.
Please analyze the given patient and inclusion criteria. Remember to include  inclusion criteria in your returned response. Please
provide your response:
"""

prompt_tmpl = PromptTemplate(qa_prompt_tmpl_str_var7)
partial_prompt_tmpl = prompt_tmpl.partial_format(tone_name="Shakespeare")
fmt_prompt = partial_prompt_tmpl.format(
    section_criteria=section_criteriaS,
    note=noteS,
)
print(fmt_prompt)

# %%
section_criteriaS=["Max Blood Glucose"]
qa_prompt_tmpl_str_var6 = """\
Your job is to decide which of the following inclusion criteria the given patient meets.
Below is a clinical note describing the patient's current health status:
---------------------
{note}
---------------------
The inclusion criteria being assessed is listed below:
{section_criteria}
---------------------
For the criteria above, use the patient's clinical note to determine whether the patient meets each criteria. Think step by step, and
justify your answer.
Format your response as a variable with following type:
* Max Blood Glucose: int , a number between o to 200, -1 if no level listed

An example of how your  response should be formatted is shown below:

Max Blood Glucose: a number

The above example is only for illustration purposes only. It does not reflect the actual criteria or patient for this task.
Please analyze the given patient and inclusion criteria. Remember to include  inclusion criteria in your returned response. Please
provide your response:
"""

prompt_tmpl = PromptTemplate(qa_prompt_tmpl_str_var6)
partial_prompt_tmpl = prompt_tmpl.partial_format(tone_name="Shakespeare")
fmt_prompt = partial_prompt_tmpl.format(
    section_criteria=section_criteriaS,
    note=noteS,
)
print(fmt_prompt)

# %%
section_criteriaS=["Diabetes mellitus (DM1, DM2, T2D, T1DM, T2DM)"]
qa_prompt_tmpl_str_var5 = """\
Your job is to decide which of the following inclusion criteria the given patient meets.
Below is a clinical note describing the patient's current health status:
---------------------
{note}
---------------------
The inclusion criteria being assessed is listed below:
{section_criteria}
---------------------
For the criteria above, use the patient's clinical note to determine whether the patient meets each criteria. Think step by step, and
justify your answer.
Format your response as a variable with following type:
* Diabetes mellitus (DM1, DM2, T2D, T1DM, T2DM): int , 1 if present, 0  if not present, -1 if no history to tell

An example of how your  response should be formatted is shown below:

Diabetes mellitus (DM1, DM2, T2D, T1DM, T2DM): 1/0/-1

The above example is only for illustration purposes only. It does not reflect the actual criteria or patient for this task.
Please analyze the given patient and inclusion criteria. Remember to include  inclusion criteria in your returned response. Please
provide your response:
"""

prompt_tmpl = PromptTemplate(qa_prompt_tmpl_str_var5)
partial_prompt_tmpl = prompt_tmpl.partial_format(tone_name="Shakespeare")
fmt_prompt = partial_prompt_tmpl.format(
    section_criteria=section_criteriaS,
    note=noteS,
)
print(fmt_prompt)

# %%
section_criteriaS=["Arterial hypertension on treatment (high bp e.g. >140, or HTN)"]
qa_prompt_tmpl_str_var4 = """\
CYour job is to decide which of the following inclusion criteria the given patient meets.
Below is a clinical note describing the patient's current health status:
---------------------
{note}
---------------------
The inclusion criteria being assessed is listed below:
{section_criteria}
---------------------
For the criteria above, use the patient's clinical note to determine whether the patient meets each criteria. Think step by step, and
justify your answer.
Format your response as a variable with following type:
* Arterial hypertension on treatment (high bp e.g. >140, or HTN): int , 1 if present, 0  if not present, -1 if no history to tell

An example of how your  response should be formatted is shown below:

Arterial hypertension on treatment (high bp e.g. >140, or HTN): 1/0/-1

The above example is only for illustration purposes only. It does not reflect the actual criteria or patient for this task.
Please analyze the given patient and inclusion criteria. Remember to include  inclusion criteria in your returned response. Please
provide your response:
"""

prompt_tmpl = PromptTemplate(qa_prompt_tmpl_str_var4)
partial_prompt_tmpl = prompt_tmpl.partial_format(tone_name="Shakespeare")
fmt_prompt = partial_prompt_tmpl.format(
    section_criteria=section_criteriaS,
    note=noteS,
)
print(fmt_prompt)

# %%
section_criteriaS=["Prior stroke or transient ischemic attack"]
qa_prompt_tmpl_str_var3 = """\
CYour job is to decide which of the following inclusion criteria the given patient meets.
Below is a clinical note describing the patient's current health status:
---------------------
{note}
---------------------
The inclusion criteria being assessed is listed below:
{section_criteria}
---------------------
For the criteria above, use the patient's clinical note to determine whether the patient meets each criteria. Think step by step, and
justify your answer.
Format your response as a variable with following type:
* Prior stroke or transient ischemic attack: int , 1 if present, 0  if not present, -1 if no history to tell

An example of how your  response should be formatted is shown below:

Prior stroke or transient ischemic attack: 1/0/-1


The above example is only for illustration purposes only. It does not reflect the actual criteria or patient for this task.
Please analyze the given patient and inclusion criteria. Remember to include  inclusion criteria in your returned response. Please
provide your response:
"""

prompt_tmpl = PromptTemplate(qa_prompt_tmpl_str_var3)
partial_prompt_tmpl = prompt_tmpl.partial_format(tone_name="Shakespeare")
fmt_prompt = partial_prompt_tmpl.format(
    section_criteria=section_criteriaS,
    note=noteS,
)
print(fmt_prompt)

# %%
section_criteriaS=["CHADS2 Score"]
qa_prompt_tmpl_str_var2 = """\
CYour job is to decide which of the following inclusion criteria the given patient meets.
Below is a clinical note describing the patient's current health status:
---------------------
{note}
---------------------
The inclusion criteria being assessed is listed below:
{section_criteria}
---------------------
For the criteria above, use the patient's clinical note to determine whether the patient meets each criteria. Think step by step, and
justify your answer.
Format your response as a variable with following type:
* CHADS2 Score: int , a number between 0 to 10 , -1 if not present


An example of how your  response should be formatted is shown below:

CHADS2 Score: a number like 1


The above example is only for illustration purposes only. It does not reflect the actual criteria or patient for this task.
Please analyze the given patient and inclusion criteria. Remember to include  inclusion criteria in your returned response. Please
provide your response:
"""

prompt_tmpl = PromptTemplate(qa_prompt_tmpl_str_var2)
partial_prompt_tmpl = prompt_tmpl.partial_format(tone_name="Shakespeare")
fmt_prompt = partial_prompt_tmpl.format(
    section_criteria=section_criteriaS,
    note=noteS,
)
print(fmt_prompt)

# %%
section_criteriaS=["Permanent, paroxysmal, or persistent afib"]
qa_prompt_tmpl_str_var1 = """\
CYour job is to decide which of the following inclusion criteria the given patient meets.
Below is a clinical note describing the patient's current health status:
---------------------
{note}
---------------------
The inclusion criteria being assessed is listed below:
{section_criteria}
---------------------
For the criteria above, use the patient's clinical note to determine whether the patient meets each criteria. Think step by step, and
justify your answer.
Format your response as a variable with following type:
* Permanent, paroxysmal, or persistent afib: int , 1 if present, 0  if not present, -1 if no history to tell


An example of how your  response should be formatted is shown below:

Permanent, paroxysmal, or persistent afib: 1/0/-1


The above example is only for illustration purposes only. It does not reflect the actual criteria or patient for this task.
Please analyze the given patient and inclusion criteria. Remember to include  inclusion criteria in your returned response. Please
provide your response:
"""

prompt_tmpl = PromptTemplate(qa_prompt_tmpl_str_var1)
partial_prompt_tmpl = prompt_tmpl.partial_format(tone_name="Shakespeare")
fmt_prompt = partial_prompt_tmpl.format(
    section_criteria=section_criteriaS,
    note=noteS,
)
print(fmt_prompt)
