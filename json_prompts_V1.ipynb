# %%
# Patient

f"""Below is a clinical note describing the patient's current health status:
{note}

# Inclusion Criterion

The inclusion criterion being assessed is:
"Please assess the patient's history for the presence of permanent, paroxysmal, or persistent atrial fibrillation (afib).
If any of these types of afib are present, respond with '1'.
If none are present, respond with '0'.
If there is no mention or history to indicate either way, respond with '-1'.
be strict in your evaluation of the patient."


# Assessment

Please provide your response:

"""#json
{
    'atrial fibrillation':
    {
        "criterion" : "Permanent, paroxysmal, or persistent atrial fibrillation",
        "answers": '',
        "type": 'bool',
        "prompt": "do you find any indication of permanent, paroxysmal, or persistent atrial fibrillation (afib)? "
    }
}

# %%
# Patient

f"""Below is a clinical note describing the patient's current health status:
{note}

# Inclusion Criterion

The inclusion criterion being assessed is:
"based on the patient's medical history and recent presentation with palpitations and new-onset atrial fibrillation, please assess and calculate the CHADS2 score.
The CHADS2 score is used to predict the risk of stroke in patients with atrial fibrillation.
If you can determine the patient's CHADS2 score based on the provided information, please provide the score.
If there is insufficient information or no mention of the CHADS2 score, please respond with '-1'."

# Assessment

Please provide your response:

"""#json
{
    'CHADS2 Score':
     {
        "criterion" : "CHADS2 Score",
        "answers": '',
        "type": 'numeric',
        "prompt": "can you find any calculated the CHADS2 score based on the provided information? "
    }
}

# %%
# Patient

f"""Below is a clinical note describing the patient's current health status:
{note}

# Inclusion Criterion

The inclusion criterion being assessed is:
" please assess whether there is any indication of a prior stroke or transient ischemic attack (TIA) based on the provided medical records.
If there is clear evidence of such a history, please respond with '1'.
If there is no indication of prior stroke or TIA, respond with '0'.
If there is insufficient information to make a determination, respond with '-1'."

# Assessment

Please provide your response:

"""#json
{
    'Prior stroke':
     {
        "criterion" : "Prior stroke or transient ischemic attack",
        "answers": '',
        "type": 'bool',
        "prompt": "can you determine if there is any mention of a prior stroke or transient ischemic attack (TIA) in the provided information?"
    }
}

# %%
# Patient

f"""Below is a clinical note describing the patient's current health status:
{note}

# Inclusion Criterion

The inclusion criterion being assessed is:
"Please review the medical records to determine if there is any indication of arterial hypertension being treated, characterized by high blood pressure (e.g., >140 mmHg), or a history of hypertension. If there is evidence of arterial hypertension being actively managed, please respond with '1'.
If there is no indication of arterial hypertension on treatment, respond with '0'.
If the information regarding arterial hypertension is not provided in the records, respond with '-1'."

# Assessment

Please provide your response:

"""#json
{
    'Arterial hypertension':
     {
        "criterion" : "Arterial hypertension on treatment",
        "answers": '',
        "type": 'bool',
        "prompt": "is there evidence of arterial hypertension being treated, defined as blood pressure being controlled (e.g., >140 mmHg)?"
    }
}

# %%
# Patient

f"""Below is a clinical note describing the patient's current health status:
{note}

# Inclusion Criterion

The inclusion criterion being assessed is:
"Considering the patient's medical records, determine the presence of diabetes mellitus (DM1, DM2, T2D, T1DM, T2DM).
Respond with: '1' if present, '0' if not present, '-1' if there is no available history."

# Assessment

Please provide your response:

"""#json
{
    'Diabetes mellitus':
     {
        "criterion" : "Diabetes mellitus (DM1, DM2, T2D, T1DM, T2DM)",
        "answers": '',
        "type": 'bool',
        "prompt": "is there any indication of diabetes mellitus (DM1, DM2, T2D, T1DM, T2DM)?"
    }
}

# %%
# Patient

f"""Below is a clinical note describing the patient's current health status:
{note}

# Inclusion Criterion

The inclusion criterion being assessed is:
"Please review the patient's medical records to identify the maximum recorded blood glucose level.
Provide the numerical value if available, otherwise indicate '-1' if not provided."

# Assessment

Please provide your response:

"""#json
{
    'Max Blood Glucose':
     {
        "criterion" : "Max Blood Glucose",
        "answers": '',
        "type": 'numeric',
        "prompt": "What is the maximum recorded blood glucose level?"
    }
}

# %%
# Patient

f"""Below is a clinical note describing the patient's current health status:
{note}

# Inclusion Criterion

The inclusion criterion being assessed is:
"Maximum A1c represents the maximum reported A1c level in the patient's medical records.
If the level is available, please provide the numerical value. If not specified, please indicate -1."

# Assessment

Please provide your response:

"""#json
{
    'Max A1c':
     {
        "criterion" : "Max A1c",
        "answers": '',
        "type": 'numeric',
        "prompt": "What is the maximum recorded A1c level?"
    }
}

# %%
# Patient

f"""Below is a clinical note describing the patient's current health status:
{note}

# Inclusion Criterion

The inclusion criterion being assessed is:
"Heart Failure: This parameter indicates whether there is a documented diagnosis of heart failure in the patient's medical records.
If the diagnosis is present, please report 1. If heart failure is not documented, please report 0.
If there is no specific indication in the records, please report -1."

# Assessment

Please provide your response:

"""#json
{
    'Heart Failure':
     {
        "criterion" : "Heart Failure",
        "answers": '',
        "type": 'bool',
        "prompt": "can you determine if there is any mention of Heart Failure in the provided information?"
    }
}

# %%
# Patient

f"""Below is a clinical note describing the patient's current health status:
{note}

# Inclusion Criterion

The inclusion criterion being assessed is:
"Left Ventricular Ejection Fraction (LVEF): This parameter indicates the percentage of blood ejected from the left ventricle of the heart with each contraction.
Please provide the LVEF mentioned in the patient's medical records. If the value is specified, please report it as a percentage. If not mentioned, please report -1.
If the value was mentioned but filtered, please report -2."

# Assessment

Please provide your response:

"""#json
{
    'ejection fraction':
     {
        "criterion" : "Left ventricular ejection fraction (lowest mentioned, LVEF, ef, ejection fraction)",
        "answers": '',
        "type": 'float',
        "prompt": "could you please provide the left ventricular ejection fraction (LVEF) mentioned in the notes?"
    }
}

# %%
# Patient

f"""Below is a clinical note describing the patient's current health status:
{note}

# Inclusion Criterion

The inclusion criterion being assessed is:
"Valvular Disease Requiring or Past Surgery (Stenosis):
Please review the patient's medical records to ascertain if there is any documented history of valvular disease requiring surgery or past surgery, specifically related to stenosis.
If such history is present, please report 1. If there is no mention of this condition, please report 0.
If there is no medical history available, please report -1."

# Assessment

Please provide your response:

"""#json
{
    'stenosis':
     {
        "criterion" : "Valvular disease requiring or past surgery (stenosis)",
        "answers": '',
        "type": 'bool',
        "prompt": "could you please determine if there is any mention of valvular disease requiring surgery or past surgery, particularly for stenosis?"
    }
}

# %%
# Patient

f"""Below is a clinical note describing the patient's current health status:
{note}

# Inclusion Criterion

The inclusion criterion being assessed is:
"Please review the patient's medical records to ascertain if there is any documented history of a planned or past ablation procedure for atrial fibrillation (afib).
If such a procedure is mentioned, please report 1.
If there is no mention of this procedure, please report 0.
If there is no medical history available regarding this procedure, please report -1."

# Assessment

Please provide your response:

"""#json
{
    'procedure for afib':
     {
        "criterion" : "Planned or past ablation procedure for afib",
        "answers": '',
        "type": 'bool',
        "prompt": "Is there any mention of a planned or past ablation procedure for atrial fibrillation (afib)?"
    }
}

# %%
# Patient

f"""Below is a clinical note describing the patient's current health status:
{note}

# Inclusion Criterion

The inclusion criterion being assessed is:
"Please review the patient's medical records to determine if there is any documented occurrence of serious bleeding within the last 6 months.
If such an event is mentioned, please report 1. If there is no mention of serious bleeding in the last 6 months, please report 0.
If there is no medical history available regarding this event, please report -1."

# Assessment

Please provide your response:

"""#json
{
    'Serious bleeding':
     {
        "criterion" : "Serious bleeding in last 6 months",
        "answers": '',
        "type": 'bool',
        "prompt": "Is there any mention of serious bleeding occurring in the last 6 months?"
    }
}

# %%
# Patient

f"""Below is a clinical note describing the patient's current health status:
{note}

# Inclusion Criterion

The inclusion criterion being assessed is:
"please indicate whether there is any documented history of peptic ulcer disease.
If documented, please report 1. If not documented, report 0.
If there is no available medical history regarding this condition, please report -1."

# Assessment

Please provide your response:

"""#json
{
    'Peptic Ulcer':
     {
        "criterion" : "History Peptic Ulcer Diseasek",
        "answers": '',
        "type": 'bool',
        "prompt": "can you determine if  there is any documented history of peptic ulcer disease in the provided information?"
    }
}

# %%
# Patient

f"""Below is a clinical note describing the patient's current health status:
{note}

# Inclusion Criterion

The inclusion criterion being assessed is:
"Please indicate in the patient's medical history whether there is any documented information about the minimum observed platelet count (PLT).
If the value is available, please report it numerically.
If there is no documentation of the minimum observed platelet count in the medical records, indicate -1."

# Assessment

Please provide your response:

"""#json
{
    'PLT':
     {
        "criterion" : "Minimum observed platelet count (PLT)",
        "answers": '',
        "type": 'numeric',
        "prompt": "What is the minimum observed platelet (PLT) count?"
    }
}

# %%
# Patient

f"""Below is a clinical note describing the patient's current health status:
{note}

# Inclusion Criterion

The inclusion criterion being assessed is:
"As a physician reviewing the patient's medical history, please indicate whether there is any documented information about the minimum observed hemoglobin (HGB).
If the value is available, please report it numerically.
If there is no documentation of the minimum observed hemoglobin count in the medical records, indicate -1."

# Assessment

Please provide your response:

"""#json
{
    'HGB':
     {
        "criterion" : "Minimum observed hemoglobin (HGB)",
        "answers": '',
        "type": 'numeric',
        "prompt": "How many is the minimum observed hemoglobin (HGB)?"
    }
}

# %%
# Patient

f"""Below is a clinical note describing the patient's current health status:
{note}

# Inclusion Criterion

The inclusion criterion being assessed is:
"Please review the patient's medical records, if there is any occurrence of stroke during the patient's admission or within 10 days prior to admission stroke is documented within this timeframe, please report 1.
If there is no documentation of stroke within this timeframe, report 0."

# Assessment

Please provide your response:

"""#json
{
    'Stroke':
     {
        "criterion" : "Stroke during admission or 10 days prior (Flag if recent, not clear 10 days)",
        "answers": '',
        "type": 'bool',
        "prompt": "Was there any occurrence of stroke during the patient's admission or within 10 days prior to admission?"
    }
}

# %%
# Patient

f"""Below is a clinical note describing the patient's current health status:
{note}

# Inclusion Criterion

The inclusion criterion being assessed is:
"Please review the patient's medical records, if there is any documented evidence of hemorrhagic tendencies or blood dyscrasias in the patient's medical history.
If documented, report 1.
If there is no documentation of such conditions, report 0."

# Assessment

Please provide your response:

"""#json
{
    'blood dyscrasias':
     {
        "criterion" : "Documented hemorrhagic tendencies or blood dyscrasias",
        "answers": '',
        "type": 'bool',
        "prompt": "Is there any documented evidence of hemorrhagic tendencies or blood dyscrasias in the patient's medical history?"
    }
}

# %%
# Patient

f"""Below is a clinical note describing the patient's current health status:
{note}

# Inclusion Criterion

The inclusion criterion being assessed is:
"Please review the patient's medical history, please indicate whether there is any documented history of alcohol abuse.
Generally, this information is not available in the Mimic IV dataset; hence, it is listed as -1.
If alcohol abuse is documented, please report 1. If no documentation of alcohol abuse is found, report 0.
If there is no mention of alcohol consumption or abstinence in the medical records, indicate -1."

# Assessment

Please provide your response:

"""#json
{
    'Alcohol abuse':
     {
        "criterion" : "Alcohol abuse",
        "answers": '',
        "type": 'bool',
        "prompt": "Is there any documented of alcohol abuse in patient's medical history?",
    }
}

# %%
# Patient

f"""Below is a clinical note describing the patient's current health status:
{note}

# Inclusion Criterion

The inclusion criterion being assessed is:
"Please review the patient's medical history, please indicate whether there is any documented history of drug abuse.
Generally, this information is not available in the Mimic IV dataset; hence, it is listed as -1.
If drug abuse is documented, please report 1. If no documentation of drug abuse is found, report 0.
If there is no mention of drug abuse in the medical records, indicate -1."

# Assessment

Please provide your response:

"""#json
{
    'Drug abuse':
     {
        "criterion" : "Drug abuse",
        "answers": '',
        "type": 'bool',
        "prompt": "Is there any documented of drug abuse in patient's medical history?"
    }
}

# %%
# Patient

f"""Below is a clinical note describing the patient's current health status:
{note}

# Inclusion Criterion

The inclusion criterion being assessed is:
"Please reviewing the patient's medical records, write the maximum observed level of serum creatinine (Creat) for the patient.
If the maximum creatinine level is documented, please report the numerical value.
If the maximum creatinine level is not mentioned in the medical records, please indicate -1."

# Assessment

Please provide your response:

"""#json
{
    'creatine':
     {
        "criterion" : "max serum creatine (Creat)",
        "answers": '',
        "type": 'numeric',
        "prompt": "What is the maximum observed level of serum creatinine (Creat) for the patient?",
    }
}

# %%
# Patient

f"""Below is a clinical note describing the patient's current health status:
{note}

# Inclusion Criterion

The inclusion criterion being assessed is:
"please reviewing the patient's medical records, report the maximum observed aspartate aminotransferase (AST) level for the patient.
If the maximum AST level is documented, please report the numerical value.
If the maximum AST level is not mentioned in the medical records, please indicate -1."

# Assessment

Please provide your response:

"""#json
{
    'AST':
     {
        "criterion" : "max aspartate aminotransferase level (AST)",
        "answers": '',
        "type": 'numeric',
        "prompt": "What is the maximum observed aspartate aminotransferase (AST) level for the patient?"
    }
}

# %%
# Patient

f"""Below is a clinical note describing the patient's current health status:
{note}

# Inclusion Criterion

The inclusion criterion being assessed is:
"By reviewing the patient's medical records, report the maximum observed level of total bilirubin (TotBili, Bili) for the patient.
If the maximum bilirubin level is documented, please report the numerical value.
If there is no documentation of the maximum bilirubin level, report -1."

# Assessment

Please provide your response:

"""#json
{
    'bilirubin':
     {
    "criterion" : "max total bilirubin (TotBili, Bili)",
    "answers": '',
    "type": 'numeric',
    "prompt": "What is the maximum observed level of total bilirubin (TotBili, Bili) for the patient?"
    }
}

# %%
# Patient

f"""Below is a clinical note describing the patient's current health status:
{note}

# Inclusion Criterion

The inclusion criterion being assessed is:
"By reviewing the patient's medical records, please indicate whether there is any documentation of bipolar disorder.
If present, report 1.
If there is no documentation of bipolar disorder, report 0."

# Assessment

Please provide your response:

"""#json
{
    'Bipolar':
     {
        "criterion" : "Bipolar",
        "answers": '',
        "type": 'bool',
        "prompt": "Is there any documentation of bipolar disorder for the patient?"
    }
}

# %%
# Patient

f"""Below is a clinical note describing the patient's current health status:
{note}

# Inclusion Criterion

The inclusion criterion being assessed is:
"By review the patient's medical records, please indicate whether there is any documentation of schizophrenia.
If present, report 1.
If there is no documentation of schizophrenia, report 0."

# Assessment

Please provide your response:

"""#json
{
    'Schizophrenic':
     {
        "criterion" : "Schizophrenic",
        "answers": '',
        "type": 'bool',
        "prompt": "Is there any documentation of schizophrenia in patient's medical records?",
    }
}

# %%
# Patient

f"""Below is a clinical note describing the patient's current health status:
{note}

# Inclusion Criterion

The inclusion criterion being assessed is:
"As a physician reviewing the patient's medical records, please indicate whether there is any documentation of major depressive disorder or depression.
If present, report 1.
If there is no documentation of major depressive disorder or depression, report 0."

# Assessment

Please provide your response:

"""#json
{
    'Depression':
     {
        "criterion" : "Major depressive disorder / Depression",
        "answers": '',
        "type": 'bool',
        "prompt": "Is there any documentation of major depressive disorder or depression?",
    }
}

# %%
# Patient

f"""Below is a clinical note describing the patient's current health status:
{note}

# Inclusion Criterion

The inclusion criterion being assessed is:
"As a healthcare provider by reviewing the patient's medical records, report if there are any documentation indicating the patient's inability to make medical decisions upon discharge, possibly due to altered mental status or consciousness.
If such documentation exists, report 1.
If there is no documentation of inability to make medical decisions, report 0."

# Assessment

Please provide your response:

"""#json
{
    'Inability decisions':
     {
        "criterion" : "Inability to make medical decisions (Discharged - mental status / consciousness)",
        "answers": '',
        "type": 'bool',
        "prompt": "Was there any documentation indicating the patient's inability to make medical decisions upon discharge, possibly due to altered mental status or consciousness?",
    }
}
